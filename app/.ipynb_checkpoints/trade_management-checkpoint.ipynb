# %%
from xtquant import xtdata
import datetime
import time
import logging
import numpy as np
import backtest as bt
from backtest import Context
import pandas as pd
import random
from xtquant.xttrader import XtQuantTrader

# %%
current_date = datetime.datetime.now()
c_date_str = current_date.strftime("%Y%m%d")
logging.basicConfig(level = logging.INFO, format = '%(asctime)s - %(levelname)s - %(message)s', filename = c_date_str + '.txt')

# %%
def trader_connect():
    # miniQMT安装路径
    mini_qmt_path = r'D:\国金QMT交易端模拟\bin.x64/../userdata_mini'
    # 创建session_id
    session_id = int(random.randint(100000, 999999))
    # 创建交易对象
    xt_trader = XtQuantTrader(mini_qmt_path, session_id)
    # 启动交易对象
    xt_trader.start()
    # 连接客户端
    connect_result = xt_trader.connect()
    print(connect_result)
    if connect_result == 0:
        print('连接成功')
    from xtquant.xttype import StockAccount
    # QMT账号
    account_id = '55004948'
    # 创建账号对象
    account = StockAccount(account_id)
    # 订阅账号
    res = xt_trader.subscribe(account)
    print(res)
    asset = xt_trader.query_stock_asset(account)
    print('账号类型：', asset.account_type)
    print('资金账号：', asset.account_id)
    print('可用金额：', asset.cash)
    print('冻结金额：', asset.frozen_cash)
    print('持仓市值：', asset.market_value)
    print('总资产：', asset.total_asset)
    return connect_result, account

# %%
connect_result, account = trader_connect()
# Out:
# 0
# 连接成功
# 0
# 账号类型： 2
# 资金账号： 55004948
# 可用金额： 10844238.05
# 冻结金额： 0.0
# 持仓市值： 8540100.2
# 总资产： 19384338.25

# %%
#coding:utf-8
import time, datetime, traceback, sys
from xtquant import xtdata
from xtquant.xttrader import XtQuantTrader, XtQuantTraderCallback
from xtquant.xttype import StockAccount
from xtquant import xtconstant

#定义一个类 创建类的实例 作为状态的容器
class _a():
    pass
A = _a()
A.bought_list = []
A.hsa = xtdata.get_stock_list_in_sector('沪深A股')

def interact():
    """执行后进入repl模式"""
    import code
    code.InteractiveConsole(locals=globals()).interact()
xtdata.download_sector_data()

def f(data):
    now = datetime.datetime.now()
    for stock in data:
        if stock not in A.hsa:
            continue
        cuurent_price = data[stock]['lastPrice']
        pre_price = data[stock]['lastClose']
        ratio = cuurent_price / pre_price - 1 if pre_price > 0 else 0
        if ratio > 0.09 and stock not in A.bought_list:
            print(f"{now} 最新价 买入 {stock} 200股")
            async_seq = xt_trader.order_stock_async(acc, stock, xtconstant.STOCK_BUY, 200, xtconstant.LATEST_PRICE, -1, 'strategy_name', stock)
            A.bought_list.append(stock)
    
class MyXtQuantTraderCallback(XtQuantTraderCallback):
    import logging
    current_date = datetime.datetime.now()
    c_date_str = current_date.strftime("%Y%m%d")
    logging.basicConfig(level = logging.INFO, format = '%(asctime)s - %(levelname)s - %(message)s', filename = c_date_str + '.txt')
    def on_disconnected(self):
        """
        连接断开
        :return:
        """
        print(datetime.datetime.now(),'连接断开回调')
        connect_result, account = trader_connect()
        while connect_result != 0:
            connect_result = trader_connect()

    def on_stock_order(self, order):
        """
        委托回报推送
        :param order: XtOrder对象
        :return:
        """
        print(datetime.datetime.now(), '委托回调', order.order_remark)
        logging.info('委托回调')


    def on_stock_trade(self, trade):
        """
        成交变动推送
        :param trade: XtTrade对象
        :return:
        """
        print(datetime.datetime.now(), '成交回调', trade.order_remark)
        logging.info('成交回调')


    def on_order_error(self, order_error):
        """
        委托失败推送
        :param order_error:XtOrderError 对象
        :return:
        """
        # print("on order_error callback")
        # print(order_error.order_id, order_error.error_id, order_error.error_msg)
        print(f"委托报错回调 {order_error.order_remark} {order_error.error_msg}")
        logging.info('委托报错回调')

    def on_cancel_error(self, cancel_error):
        """
        撤单失败推送
        :param cancel_error: XtCancelError 对象
        :return:
        """
        print(datetime.datetime.now(), sys._getframe().f_code.co_name)

    def on_order_stock_async_response(self, response):
        """
        异步下单回报推送
        :param response: XtOrderResponse 对象
        :return:
        """
        print(f"异步委托回调 {response.order_remark}")
        logging.info('异步委托回调')

    def on_cancel_order_stock_async_response(self, response):
        """
        :param response: XtCancelOrderResponse 对象
        :return:
        """
        print(datetime.datetime.now(), sys._getframe().f_code.co_name)

    def on_account_status(self, status):
        """
        :param response: XtAccountStatus 对象
        :return:
        """
        print(datetime.datetime.now(), sys._getframe().f_code.co_name)


if __name__ == '__main__':
    print("start")
    #指定客户端所在路径
    path = r'D:\国金QMT交易端模拟\bin.x64/../userdata_mini'
    # 生成session id 整数类型 同时运行的策略不能重复
    session_id = int(time.time())
    xt_trader = XtQuantTrader(path, session_id)
    # 开启主动请求接口的专用线程 开启后在on_stock_xxx回调函数里调用XtQuantTrader.query_xxx函数不会卡住回调线程，但是查询和推送的数据在时序上会变得不确定
    # 详见: http://docs.thinktrader.net/vip/pages/ee0e9b/#开启主动请求接口的专用线程
    # xt_trader.set_relaxed_response_order_enabled(True)

    # 创建资金账号为 800068 的证券账号对象
    acc = StockAccount('55004948', 'STOCK')
    # 创建交易回调类对象，并声明接收回调
    callback = MyXtQuantTraderCallback()
    xt_trader.register_callback(callback)
    # 启动交易线程
    xt_trader.start()
    # 建立交易连接，返回0表示连接成功
    connect_result = xt_trader.connect()
    print('建立交易连接，返回0表示连接成功', connect_result)
    # 对交易回调进行订阅，订阅后可以收到交易主推，返回0表示订阅成功
    subscribe_result = xt_trader.subscribe(acc)
    print('对交易回调进行订阅，订阅后可以收到交易主推，返回0表示订阅成功', subscribe_result)

    #这一行是注册全推回调函数 包括下单判断 安全起见处于注释状态 确认理解效果后再放开
    # xtdata.subscribe_whole_quote(["SH", "SZ"], callback=f)
    # 阻塞主线程退出
    #xt_trader.run_forever()
    # 如果使用vscode pycharm等本地编辑器 可以进入交互模式 方便调试 （把上一行的run_forever注释掉 否则不会执行到这里）
    #interact()
# Out:
# ***** xtdata连接成功 *****
# 服务信息: {'tag': 'sp3', 'version': '1.0'}
# 服务地址: 127.0.0.1:58610
# 数据路径: D:\国金QMT交易端模拟\bin.x64/../userdata_mini/datadir
# 设置xtdata.enable_hello = False可隐藏此消息
#
# start
# 建立交易连接，返回0表示连接成功 -1
# 对交易回调进行订阅，订阅后可以收到交易主推，返回0表示订阅成功 -1

# %% [markdown]
# ***<font color=steel
#     size=5
#        face=雅黑>
# <mark>买入</mark>
# </font>***

# %%
def get_hold_position():
    # get hold position
    positions = xt_trader.query_stock_positions(account)
    #print("positions:", len(positions))
    #if len(positions) != 0:
    #    print("last position:", positions[-1])
        
    stock_list = []
    position_dict = {}
    for i in range(len(positions)):
        #print("{0} {1} {2} {3} {4} {5}".format(positions[i].account_id, 
        #                           positions[i].stock_code, 
        #                           positions[i].volume, 
        #                           positions[i].open_price, 
        #                           positions[i].market_value, 
        #                           positions[i].avg_price))
        position = {
            "stock_code": positions[i].stock_code, 
            "volume": positions[i].volume, 
            "can_use_volume": positions[i].can_use_volume, 
            "open_price": positions[i].open_price, 
            "market_value": positions[i].market_value, 
            "avg_price": positions[i].avg_price
        }
        stock_list.append(positions[i].stock_code)
        position_dict[positions[i].stock_code] = position
    return stock_list, position_dict

# %% [markdown]
# ***<font color=steel
#     size=5
#        face=雅黑>
# <mark>成交记录读取</mark>
# </font>***

# %%
current_date = datetime.datetime.now() #- datetime.timedelta(days=1)
c_date_str = current_date.strftime("%Y%m%d")
trade_df = pd.read_csv('trade_record_' + c_date_str + '.csv')
trade_list = trade_df['stock_code'].to_list()
trade_list

# %%
ret

# %%
while True:
    hour = datetime.datetime.now().hour
    minute = datetime.datetime.now().minute
    cur_time = hour * 100 + minute
    logging.info("check time: " + str(cur_time))
    if cur_time < 930:
        logging.info("NOT TRADING TIME")
        time.sleep(60)
        continue
    else:
        logging.info("START BUYING")
        break

# %%
#TODO: 当日已卖出不再买入 √
#TODO: 已持有股票不再买入 √
#TODO: order_target_value √
#TODO: 下跌过程中放量
#TODO：保存成交历史 √
#TODO: 剔除停牌证券 √
#TODO: 降低行业集中度
current_date = datetime.datetime.now() #+ datetime.timedelta(days=1)
c_date_str = current_date.strftime("%Y%m%d")
print(c_date_str)
#ret.to_csv('test_data_'+c_date_str+'.csv')
ret = pd.read_csv('test_data_'+c_date_str+'.csv',index_col=0)
######################STRATEGY########################################
# ETF close price may less than 1, otherwise must bigger than 1
stock_df = ret[(ret['va0_va1_5'] >= 3) & (ret['va1_5'] >= 100000)].sort_values(['va0_va1_5', 'va1_5_va5_10'], ascending=False)
######################################################################
stock_list = stock_df.index.to_list()
print('stock_list: ', stock_list)

bought_stock_list, position_dict = get_hold_position()
print('bought_stock_list: ', bought_stock_list)
print('trade_list: ', trade_list)

current_date = datetime.datetime.now() + datetime.timedelta(days=1)
c_date_str = current_date.strftime("%Y%m%d")
print(c_date_str)
order_list = []
for stock in stock_list:
    print(stock)
    code_list = [stock]
    openInt = xtdata.get_full_tick(code_list)[stock]['openInt']
    print(openInt)
    if openInt == 1:
        continue
    if stock not in bought_stock_list and stock not in trade_list:
        order_list.append(stock)
        
#stock_list = ['588680.SH']
print("order_list: ", order_list)
total_value = 2000000
order_value = int(total_value/len(order_list))
print(order_value)
for stock in order_list:
    #TODO：get_market_data_ex
    code = stock.split('.')[0]
    #print(code)
    market = stock.split('.')[1]
    
    #print(xtdata.get_full_tick(code_list))
    global context
    context = Context(market, 100000000, c_date_str, c_date_str)
    context.bkt_dt = current_date.strftime("%Y%m%d")
    hist_data = bt.get_hist_data_by_count(context, code, 1, 'none', 'tick', ['lastPrice'])
    #logging.info(hist_data)
    #print(hist_data)
    last_price = hist_data.values[0][0]
    print('last_price: ', last_price)
    if last_price <= 0:
        continue
    amount = int(order_value / last_price)
    print('order amount: ', amount)
    if amount % 100 != 0:
        amount = int(amount / 100) * 100
        logging.info('adjusted to buyable amount ' + str(amount))
        
    print("#############actual order: ", stock)
    async_seq = xt_trader.order_stock_async(acc, 
                                                stock, 
                                                xtconstant.STOCK_BUY, 
                                                amount, 
                                                xtconstant.FIX_PRICE, 
                                                last_price, 
                                                'strategy_buy', 
                                                stock)
# Out:
# 20240809
# stock_list:  ['600192.SH', '600105.SH', '002339.SZ', '300267.SZ', '603333.SH', '002298.SZ', '600343.SH', '600355.SH', '300265.SZ', '300261.SZ', '300647.SZ', '002792.SZ', '300102.SZ', '603323.SH', '300189.SZ', '603421.SH', '601128.SH', '300269.SZ', '600280.SH', '603618.SH', '000890.SZ', '000949.SZ', '600313.SH', '000404.SZ', '000972.SZ', '002374.SZ', '600397.SH', '600753.SH']
# bought_stock_list:  ['510150.SH', '512000.SH', '512100.SH', '512500.SH', '512680.SH', '512880.SH', '512900.SH', '513000.SH', '513090.SH', '513110.SH', '513280.SH', '513350.SH', '513360.SH', '513750.SH', '513800.SH', '513900.SH', '515180.SH', '515300.SH', '515450.SH', '560170.SH', '562000.SH', '600057.SH', '600061.SH', '600105.SH', '600109.SH', '600125.SH', '600126.SH', '600135.SH', '600192.SH', '600221.SH', '600257.SH', '600280.SH', '600313.SH', '600318.SH', '600326.SH', '600343.SH', '600355.SH', '600369.SH', '600396.SH', '600397.SH', '600556.SH', '600653.SH', '600753.SH', '600906.SH', '600999.SH', '601108.SH', '601111.SH', '601128.SH', '601136.SH', '601198.SH', '601211.SH', '601375.SH', '601377.SH', '601388.SH', '601515.SH', '601528.SH', '601555.SH', '601696.SH', '601698.SH', '601788.SH', '601878.SH', '601881.SH', '601933.SH', '603259.SH', '603333.SH', '603421.SH', '603618.SH', '603778.SH', '603883.SH', '000017.SZ', '000068.SZ', '000404.SZ', '000651.SZ', '000702.SZ', '000715.SZ', '000776.SZ', '000783.SZ', '000890.SZ', '000928.SZ', '000949.SZ', '001213.SZ', '002009.SZ', '002031.SZ', '002035.SZ', '002219.SZ', '002291.SZ', '002298.SZ', '002303.SZ', '002317.SZ', '002329.SZ', '002339.SZ', '002343.SZ', '002366.SZ', '002423.SZ', '002425.SZ', '002471.SZ', '002495.SZ', '002515.SZ', '002519.SZ', '002542.SZ', '002555.SZ', '002561.SZ', '002587.SZ', '002630.SZ', '002647.SZ', '002659.SZ', '002673.SZ', '002775.SZ', '002792.SZ', '002797.SZ', '159513.SZ', '159566.SZ', '159612.SZ', '159629.SZ', '159673.SZ', '159736.SZ', '159776.SZ', '159841.SZ', '159850.SZ', '159919.SZ', '159930.SZ', '159934.SZ', '300005.SZ', '300015.SZ', '300070.SZ', '300071.SZ', '300091.SZ', '300102.SZ', '300180.SZ', '300215.SZ', '300261.SZ', '300267.SZ', '300269.SZ', '300352.SZ', '300381.SZ', '300569.SZ', '300638.SZ', '300647.SZ', '300759.SZ']
# trade_list:  ['600280.SH', '600343.SH', '600753.SH', '000702.SZ', '002647.SZ', '300102.SZ', '600192.SH', '000715.SZ', '600397.SH', '601933.SH', '002561.SZ', '300261.SZ', '601198.SH', '300267.SZ', '002219.SZ', '300269.SZ', '601698.SH', '002298.SZ', '600318.SH', '513360.SH']
# 20240810
# 600192.SH
# 15
# 600105.SH
# 15
# 002339.SZ
# 15
# 300267.SZ
# 15
# 603333.SH
# 15
# 002298.SZ
# 15
# 600343.SH
# 15
# 600355.SH
# 15
# 300265.SZ
# 15
# 300261.SZ
# 15
# 300647.SZ
# 15
# 002792.SZ
# 15
# 300102.SZ
# 15
# 603323.SH
# 15
# 300189.SZ
# 15
# 603421.SH
# 15
# 601128.SH
# 15
# 300269.SZ
# 15
# 600280.SH
# 15
# 603618.SH
# 15
# 000890.SZ
# 15
# 000949.SZ
# 15
# 600313.SH
# 15
# 000404.SZ
# 15
# 000972.SZ
# 15
# 002374.SZ
# 15
# 600397.SH
# 15
# 600753.SH
# 15
# order_list:  ['300265.SZ', '603323.SH', '300189.SZ', '000972.SZ', '002374.SZ']
# 400000
# last_price:  7.2700000000000005
# order amount:  55020
# #############actual order:  300265.SZ
# 异步委托回调 300265.SZ
# 2024-08-09 15:51:04.682498 委托回调 300265.SZ
# 2024-08-09 15:51:04.683495 委托回调 300265.SZ
# 2024-08-09 15:51:04.683495 成交回调 300265.SZ
# 2024-08-09 15:51:04.684492 委托回调 300265.SZ
# last_price:  4.55
# order amount:  87912
# #############actual order:  603323.SH
# 异步委托回调 603323.SH
# 2024-08-09 15:51:05.285882 委托回调 603323.SH
# 2024-08-09 15:51:05.285882 成交回调 603323.SH
# 2024-08-09 15:51:05.285882 委托回调 603323.SH
# last_price:  2.32
# order amount:  172413
# #############actual order:  300189.SZ
# 异步委托回调 300189.SZ
# 2024-08-09 15:51:09.432785 委托回调 300189.SZ
# 2024-08-09 15:51:09.432785 成交回调 300189.SZ
# 2024-08-09 15:51:09.433783 委托回调 300189.SZ
# last_price:  2.59
# order amount:  154440
# #############actual order:  000972.SZ
# 异步委托回调 000972.SZ
# 2024-08-09 15:51:09.775867 委托回调 000972.SZ
# 2024-08-09 15:51:09.776864 委托回调 000972.SZ
# 2024-08-09 15:51:09.777863 成交回调 000972.SZ
# 2024-08-09 15:51:09.777863 委托回调 000972.SZ
# last_price:  1.83
# order amount:  218579
# #############actual order:  002374.SZ
# 异步委托回调 002374.SZ
# 2024-08-09 15:51:09.875547 委托回调 002374.SZ
# 2024-08-09 15:51:09.921424 成交回调 002374.SZ
# 2024-08-09 15:51:09.922423 委托回调 002374.SZ
# 2024-08-09 16:01:29.231179 on_account_status
# 2024-08-09 16:01:37.811218 on_account_status
# 2024-08-09 20:18:26.830695 on_account_status
# 2024-08-09 20:18:27.389203 on_account_status
# 2024-08-09 20:18:38.726863 on_account_status
# 2024-08-09 20:18:39.287363 on_account_status
# 2024-08-09 20:18:40.278709 on_account_status
# 2024-08-09 20:35:02.210608 on_account_status
# 2024-08-09 20:35:14.666277 on_account_status

# %%
stock = '520660.SH'
code_list = [stock]
xtdata.get_full_tick(code_list)[stock]
# Out:
# {'timetag': '20240805 15:29:16',
#  'lastPrice': 0.86,
#  'open': 0.886,
#  'high': 0.888,
#  'low': 0.855,
#  'lastClose': 0.897,
#  'amount': 61095300,
#  'volume': 699980,
#  'pvolume': 69998000,
#  'stockStatus': 0,
#  'openInt': 15,
#  'settlementPrice': 0,
#  'lastSettlementPrice': 0,
#  'askPrice': [0.865, 0.866, 0.867, 0.868, 0.869],
#  'bidPrice': [0.858, 0.857, 0.856, 0.855, 0.854],
#  'askVol': [424, 604, 2, 4, 4],
#  'bidVol': [2456, 2937, 299, 825, 11]}

# %%
code = '300053'
global context
context = Context(market, 100000000, c_date_str, c_date_str)
context.bkt_dt = current_date.strftime("%Y%m%d")
hist_data = bt.get_hist_data_by_count(context, code, 1, 'none', 'tick', ['lastPrice'])
hist_data
# Out:
#                 lastPrice
# 20240731153000      11.77

# %%
current_date = datetime.datetime.now() + datetime.timedelta(days=1)
c_date_str = current_date.strftime("%Y%m%d")
#c_date_str = '20240731'
print(c_date_str)
#ret.to_csv('test_data_'+c_date_str+'.csv')
ret = pd.read_csv('test_data_'+c_date_str+'.csv',index_col=0)
# ETF close price may less than 1, otherwise must bigger than 1
#stock_df = ret[(ret['va0_va1_5'] >= 3) & (ret['va1_5'] >= 100000)].sort_values(['va0_va1_5', 'va1_5_va5_10'], ascending=False)
#ode_list = ['000651.SZ', '600157.SH']
#xtdata.get_full_tick(code_list)
#证券状态
#0,10 - 默认为未知
#1  -  停牌
#11 - 开盘前S
#12 - 集合竞价时段C
#13 - 连续交易T
#14 - 休市B
#15 - 闭市E
#16 - 波动性中断V
#17 - 临时停牌P
#18 - 收盘集合竞价U
#19 - 盘中集合竞价M
#20 - 暂停交易至闭市N
#21 - 获取字段异常
#22 - 盘后固定价格行情
#23 - 盘后固定价格行情完毕
#stock_df[['close', 'amount', 'preClose', 'va1_5', 'va5_10', 'va1_5_va5_10', 'va0_va1_5']]
stock_df = ret[(ret['amo0_amo1_5'] >= 5) & (ret['amo1_5'] >= 100000000)].sort_values(['amo0_amo1_5', 'amo1_5_amo5_10'], ascending=False)
stock_df[['close', 'amount', 'preClose', 'amo1_5', 'amo5_10', 'amo1_5_amo5_10', 'amo0_amo1_5']]
# Out:
# 20240801
#             close        amount  preClose       amo1_5      amo5_10  \
# 300061.SZ   8.710  1.650111e+09     7.260  113313442.4  109919524.8
# 600157.SH   1.100  1.822557e+09     1.120  208310965.4  186791228.2
# 600635.SH   3.890  1.723816e+09     4.280  226275503.2   89329082.8
# 601698.SH  17.570  2.254384e+09    16.860  336903964.8  189687582.4
# 300053.SZ  11.770  1.609144e+09    10.810  252974896.6  112644075.4
# 601059.SH  14.760  7.943413e+08    13.460  149208746.6  185789526.0
# 300803.SZ  40.380  1.093280e+09    34.360  207700703.2  201019540.2
# 600386.SH   4.270  5.279982e+08     3.880  101310252.2  168126492.8
# 603988.SH  12.060  5.434244e+08    10.960  104984624.4   20162901.2
# 601099.SH   3.410  1.951486e+09     3.100  384629703.2  432790457.0
# 513090.SH   0.935  2.034624e+09     0.894  403315821.2  461690236.2
# 601881.SH  10.890  1.574004e+09    10.040  314539128.8  405055008.8
# 600721.SH   6.810  5.773470e+08     6.190  115400559.0  184921572.4
#
#            amo1_5_amo5_10  amo0_amo1_5
# 300061.SZ        1.030876    14.562363
# 600157.SH        1.115207     8.749211
# 600635.SH        2.533055     7.618218
# 601698.SH        1.776099     6.691472
# 300053.SZ        2.245790     6.360883
# 601059.SH        0.803106     5.323691
# 300803.SZ        1.033236     5.263727
# 600386.SH        0.602584     5.211696
# 603988.SH        5.206821     5.176228
# 601099.SH        0.888720     5.073676
# 513090.SH        0.873564     5.044741
# 601881.SH        0.776534     5.004160
# 600721.SH        0.624051     5.002982

# %%
trades = xt_trader.query_stock_trades(account)
#traded_id	str	成交编号
#traded_time	int	成交时间
#traded_price	float	成交均价
#traded_volume	int	成交数量
#traded_amount	float	成交金额
#order_id	int	订单编号
#order_sysid	str	柜台合同编号
#strategy_name	str	策略名称
#order_remark	str	委托备注
#direction

#print(trades)
for i in range(len(trades)):
    print("account_id: ", trades[i].account_id)
    print("stock_code: ", trades[i].stock_code)
    print("order_type: ", trades[i].order_type)
    print("traded_id: ", trades[i].traded_id)
    print("traded_time: ", trades[i].traded_time)
    print("traded_price: ", trades[i].traded_price)
    print("traded_volume: ", trades[i].traded_volume)
    print("traded_amount: ", trades[i].traded_amount)
    print("order_id: ", trades[i].order_id)
    print("strategy_name: ", trades[i].strategy_name)
    print("##################################")
# Out:
# account_id:  55004948
# stock_code:  513400.SH
# order_type:  24
# traded_id:  50009564
# traded_time:  1721615045
# traded_price:  1.057
# traded_volume:  1300
# traded_amount:  1374.1
# order_id:  1090535588
# strategy_name:  strategy_sell
# ##################################
# account_id:  55004948
# stock_code:  513730.SH
# order_type:  24
# traded_id:  50009565
# traded_time:  1721615046
# traded_price:  1.153
# traded_volume:  100
# traded_amount:  115.3
# order_id:  1090535597
# strategy_name:  strategy_sell
# ##################################
# account_id:  55004948
# stock_code:  515450.SH
# order_type:  24
# traded_id:  50009566
# traded_time:  1721615047
# traded_price:  1.31
# traded_volume:  1000
# traded_amount:  1310.0
# order_id:  1090535604
# strategy_name:  strategy_sell
# ##################################
# account_id:  55004948
# stock_code:  517520.SH
# order_type:  24
# traded_id:  50009567
# traded_time:  1721615050
# traded_price:  1.241
# traded_volume:  100
# traded_amount:  124.10000000000001
# order_id:  1090535615
# strategy_name:  strategy_sell
# ##################################
# account_id:  55004948
# stock_code:  561560.SH
# order_type:  24
# traded_id:  50009568
# traded_time:  1721615051
# traded_price:  1.259
# traded_volume:  100
# traded_amount:  125.89999999999999
# order_id:  1090535619
# strategy_name:  strategy_sell
# ##################################
# account_id:  55004948
# stock_code:  600675.SH
# order_type:  24
# traded_id:  50009569
# traded_time:  1721615052
# traded_price:  2.59
# traded_volume:  1000
# traded_amount:  2590.0
# order_id:  1090535632
# strategy_name:  strategy_sell
# ##################################
# account_id:  55004948
# stock_code:  600676.SH
# order_type:  24
# traded_id:  50009570
# traded_time:  1721615053
# traded_price:  3.74
# traded_volume:  3000
# traded_amount:  11220.0
# order_id:  1090535636
# strategy_name:  strategy_sell
# ##################################
# account_id:  55004948
# stock_code:  600859.SH
# order_type:  24
# traded_id:  50009571
# traded_time:  1721615053
# traded_price:  13.32
# traded_volume:  100
# traded_amount:  1332.0
# order_id:  1090535641
# strategy_name:  strategy_sell
# ##################################
# account_id:  55004948
# stock_code:  603336.SH
# order_type:  24
# traded_id:  50009572
# traded_time:  1721615055
# traded_price:  3.28
# traded_volume:  3100
# traded_amount:  10168.0
# order_id:  1090535649
# strategy_name:  strategy_sell
# ##################################
# account_id:  55004948
# stock_code:  601933.SH
# order_type:  24
# traded_id:  50045755
# traded_time:  1721627735
# traded_price:  2.26
# traded_volume:  1000
# traded_amount:  2260.0
# order_id:  1090606315
# strategy_name:  strategy_sell
# ##################################
# account_id:  55004948
# stock_code:  603628.SH
# order_type:  24
# traded_id:  50045758
# traded_time:  1721627739
# traded_price:  13.21
# traded_volume:  1000
# traded_amount:  13210.0
# order_id:  1090606353
# strategy_name:  strategy_sell
# ##################################
# account_id:  55004948
# stock_code:  600650.SH
# order_type:  24
# traded_id:  50051582
# traded_time:  1721630445
# traded_price:  14.81
# traded_volume:  3000
# traded_amount:  44430.0
# order_id:  1090624137
# strategy_name:  strategy_sell
# ##################################
# account_id:  55004948
# stock_code:  600125.SH
# order_type:  23
# traded_id:  50057164
# traded_time:  1721632991
# traded_price:  6.03
# traded_volume:  1000
# traded_amount:  6030.0
# order_id:  1090640072
# strategy_name:  strategy_buy
# ##################################
# account_id:  55004948
# stock_code:  600460.SH
# order_type:  23
# traded_id:  50057165
# traded_time:  1721632991
# traded_price:  21.43
# traded_volume:  1000
# traded_amount:  21430.0
# order_id:  1090640083
# strategy_name:  strategy_buy
# ##################################
# account_id:  55004948
# stock_code:  600030.SH
# order_type:  23
# traded_id:  50057166
# traded_time:  1721632991
# traded_price:  20.19
# traded_volume:  1000
# traded_amount:  20190.0
# order_id:  1090640081
# strategy_name:  strategy_buy
# ##################################
# account_id:  55004948
# stock_code:  601360.SH
# order_type:  23
# traded_id:  50057167
# traded_time:  1721632991
# traded_price:  7.58
# traded_volume:  1000
# traded_amount:  7580.0
# order_id:  1090640105
# strategy_name:  strategy_buy
# ##################################
# account_id:  55004948
# stock_code:  515950.SH
# order_type:  23
# traded_id:  50057168
# traded_time:  1721632991
# traded_price:  0.808
# traded_volume:  1000
# traded_amount:  808.0
# order_id:  1090640109
# strategy_name:  strategy_buy
# ##################################
# account_id:  55004948
# stock_code:  560050.SH
# order_type:  23
# traded_id:  50057169
# traded_time:  1721632991
# traded_price:  0.756
# traded_volume:  1000
# traded_amount:  756.0
# order_id:  1090640100
# strategy_name:  strategy_buy
# ##################################
# account_id:  55004948
# stock_code:  600536.SH
# order_type:  23
# traded_id:  50057170
# traded_time:  1721632991
# traded_price:  32.11
# traded_volume:  1000
# traded_amount:  32110.0
# order_id:  1090640086
# strategy_name:  strategy_buy
# ##################################
# account_id:  55004948
# stock_code:  515710.SH
# order_type:  23
# traded_id:  50057171
# traded_time:  1721632991
# traded_price:  0.587
# traded_volume:  1000
# traded_amount:  587.0
# order_id:  1090640097
# strategy_name:  strategy_buy
# ##################################
# account_id:  55004948
# stock_code:  601225.SH
# order_type:  23
# traded_id:  50057172
# traded_time:  1721632991
# traded_price:  24.25
# traded_volume:  1000
# traded_amount:  24250.0
# order_id:  1090640107
# strategy_name:  strategy_buy
# ##################################
# account_id:  55004948
# stock_code:  600676.SH
# order_type:  23
# traded_id:  50057173
# traded_time:  1721632991
# traded_price:  3.74
# traded_volume:  1000
# traded_amount:  3740.0
# order_id:  1090640098
# strategy_name:  strategy_buy
# ##################################
# account_id:  55004948
# stock_code:  600624.SH
# order_type:  23
# traded_id:  50057174
# traded_time:  1721632991
# traded_price:  3.27
# traded_volume:  1000
# traded_amount:  3270.0
# order_id:  1090640110
# strategy_name:  strategy_buy
# ##################################
# account_id:  55004948
# stock_code:  515300.SH
# order_type:  23
# traded_id:  50057175
# traded_time:  1721632991
# traded_price:  1.418
# traded_volume:  1000
# traded_amount:  1418.0
# order_id:  1090640113
# strategy_name:  strategy_buy
# ##################################
# account_id:  55004948
# stock_code:  588380.SH
# order_type:  23
# traded_id:  50057176
# traded_time:  1721632991
# traded_price:  0.474
# traded_volume:  1000
# traded_amount:  474.0
# order_id:  1090640117
# strategy_name:  strategy_buy
# ##################################
# account_id:  55004948
# stock_code:  516920.SH
# order_type:  23
# traded_id:  50057177
# traded_time:  1721632991
# traded_price:  0.561
# traded_volume:  1000
# traded_amount:  561.0
# order_id:  1090640085
# strategy_name:  strategy_buy
# ##################################
# account_id:  55004948
# stock_code:  510100.SH
# order_type:  23
# traded_id:  50057178
# traded_time:  1721632991
# traded_price:  1.229
# traded_volume:  1000
# traded_amount:  1229.0
# order_id:  1090640115
# strategy_name:  strategy_buy
# ##################################
# account_id:  55004948
# stock_code:  603680.SH
# order_type:  23
# traded_id:  50057179
# traded_time:  1721632991
# traded_price:  7.49
# traded_volume:  1000
# traded_amount:  7490.0
# order_id:  1090640128
# strategy_name:  strategy_buy
# ##################################
# account_id:  55004948
# stock_code:  513920.SH
# order_type:  23
# traded_id:  50057180
# traded_time:  1721632992
# traded_price:  1.162
# traded_volume:  1000
# traded_amount:  1162.0
# order_id:  1090640088
# strategy_name:  strategy_buy
# ##################################
# account_id:  55004948
# stock_code:  515400.SH
# order_type:  23
# traded_id:  50057181
# traded_time:  1721632992
# traded_price:  0.606
# traded_volume:  1000
# traded_amount:  606.0
# order_id:  1090640125
# strategy_name:  strategy_buy
# ##################################
# account_id:  55004948
# stock_code:  600171.SH
# order_type:  23
# traded_id:  50057182
# traded_time:  1721632992
# traded_price:  24.56
# traded_volume:  1000
# traded_amount:  24560.0
# order_id:  1090640119
# strategy_name:  strategy_buy
# ##################################
# account_id:  55004948
# stock_code:  516920.SH
# order_type:  23
# traded_id:  50057283
# traded_time:  1721638427
# traded_price:  0.561
# traded_volume:  1000
# traded_amount:  561.0
# order_id:  1090642414
# strategy_name:  strategy_buy
# ##################################
# account_id:  55004948
# stock_code:  600125.SH
# order_type:  23
# traded_id:  50057284
# traded_time:  1721638427
# traded_price:  6.03
# traded_volume:  1000
# traded_amount:  6030.0
# order_id:  1090642401
# strategy_name:  strategy_buy
# ##################################
# account_id:  55004948
# stock_code:  600460.SH
# order_type:  23
# traded_id:  50057285
# traded_time:  1721638427
# traded_price:  21.43
# traded_volume:  1000
# traded_amount:  21430.0
# order_id:  1090642412
# strategy_name:  strategy_buy
# ##################################
# account_id:  55004948
# stock_code:  513920.SH
# order_type:  23
# traded_id:  50057286
# traded_time:  1721638427
# traded_price:  1.162
# traded_volume:  1000
# traded_amount:  1162.0
# order_id:  1090642417
# strategy_name:  strategy_buy
# ##################################
# account_id:  55004948
# stock_code:  600030.SH
# order_type:  23
# traded_id:  50057287
# traded_time:  1721638427
# traded_price:  20.19
# traded_volume:  1000
# traded_amount:  20190.0
# order_id:  1090642410
# strategy_name:  strategy_buy
# ##################################
# account_id:  55004948
# stock_code:  600536.SH
# order_type:  23
# traded_id:  50057288
# traded_time:  1721638427
# traded_price:  32.11
# traded_volume:  1000
# traded_amount:  32110.0
# order_id:  1090642415
# strategy_name:  strategy_buy
# ##################################
# account_id:  55004948
# stock_code:  000421.SZ
# order_type:  24
# traded_id:  1002000637365146
# traded_time:  1721615056
# traded_price:  5.12
# traded_volume:  200
# traded_amount:  1024.0
# order_id:  1090535660
# strategy_name:  strategy_sell
# ##################################
# account_id:  55004948
# stock_code:  000421.SZ
# order_type:  24
# traded_id:  1002000637365147
# traded_time:  1721615056
# traded_price:  5.12
# traded_volume:  200
# traded_amount:  1024.0
# order_id:  1090535660
# strategy_name:  strategy_sell
# ##################################
# account_id:  55004948
# stock_code:  000421.SZ
# order_type:  24
# traded_id:  1002000637365148
# traded_time:  1721615056
# traded_price:  5.12
# traded_volume:  200
# traded_amount:  1024.0
# order_id:  1090535660
# strategy_name:  strategy_sell
# ##################################
# account_id:  55004948
# stock_code:  000953.SZ
# order_type:  24
# traded_id:  1002000637365155
# traded_time:  1721615059
# traded_price:  2.71
# traded_volume:  2000
# traded_amount:  5420.0
# order_id:  1090535675
# strategy_name:  strategy_sell
# ##################################
# account_id:  55004948
# stock_code:  002321.SZ
# order_type:  24
# traded_id:  1002000637365162
# traded_time:  1721615061
# traded_price:  1.48
# traded_volume:  2000
# traded_amount:  2960.0
# order_id:  1090535692
# strategy_name:  strategy_sell
# ##################################
# account_id:  55004948
# stock_code:  002400.SZ
# order_type:  24
# traded_id:  1002000637365164
# traded_time:  1721615061
# traded_price:  4.92
# traded_volume:  100
# traded_amount:  492.0
# order_id:  1090535694
# strategy_name:  strategy_sell
# ##################################
# account_id:  55004948
# stock_code:  002613.SZ
# order_type:  24
# traded_id:  1002000637365169
# traded_time:  1721615061
# traded_price:  3.59
# traded_volume:  3000
# traded_amount:  10770.0
# order_id:  1090535698
# strategy_name:  strategy_sell
# ##################################
# account_id:  55004948
# stock_code:  159518.SZ
# order_type:  24
# traded_id:  1002000637365173
# traded_time:  1721615063
# traded_price:  1.037
# traded_volume:  500
# traded_amount:  518.5
# order_id:  1090535701
# strategy_name:  strategy_sell
# ##################################
# account_id:  55004948
# stock_code:  159529.SZ
# order_type:  24
# traded_id:  1002000637365176
# traded_time:  1721615063
# traded_price:  1.119
# traded_volume:  100
# traded_amount:  111.9
# order_id:  1090535702
# strategy_name:  strategy_sell
# ##################################
# account_id:  55004948
# stock_code:  300207.SZ
# order_type:  24
# traded_id:  1002000637365184
# traded_time:  1721615066
# traded_price:  17.58
# traded_volume:  100
# traded_amount:  1757.9999999999998
# order_id:  1090535718
# strategy_name:  strategy_sell
# ##################################
# account_id:  55004948
# stock_code:  300637.SZ
# order_type:  24
# traded_id:  1002000637423321
# traded_time:  1721627790
# traded_price:  10.27
# traded_volume:  2000
# traded_amount:  20540.0
# order_id:  1090606727
# strategy_name:  strategy_sell
# ##################################
# account_id:  55004948
# stock_code:  300379.SZ
# order_type:  23
# traded_id:  1002000637455032
# traded_time:  1721632991
# traded_price:  8.32
# traded_volume:  1000
# traded_amount:  8320.0
# order_id:  1090640076
# strategy_name:  strategy_buy
# ##################################
# account_id:  55004948
# stock_code:  002531.SZ
# order_type:  23
# traded_id:  1002000637455034
# traded_time:  1721632991
# traded_price:  8.48
# traded_volume:  1000
# traded_amount:  8480.0
# order_id:  1090640079
# strategy_name:  strategy_buy
# ##################################
# account_id:  55004948
# stock_code:  002077.SZ
# order_type:  23
# traded_id:  1002000637455036
# traded_time:  1721632991
# traded_price:  12.12
# traded_volume:  1000
# traded_amount:  12120.0
# order_id:  1090640082
# strategy_name:  strategy_buy
# ##################################
# account_id:  55004948
# stock_code:  000008.SZ
# order_type:  23
# traded_id:  1002000637455038
# traded_time:  1721632991
# traded_price:  2.03
# traded_volume:  1000
# traded_amount:  2029.9999999999998
# order_id:  1090640071
# strategy_name:  strategy_buy
# ##################################
# account_id:  55004948
# stock_code:  300077.SZ
# order_type:  23
# traded_id:  1002000637455040
# traded_time:  1721632991
# traded_price:  10.68
# traded_volume:  1000
# traded_amount:  10680.0
# order_id:  1090640068
# strategy_name:  strategy_buy
# ##################################
# account_id:  55004948
# stock_code:  300460.SZ
# order_type:  23
# traded_id:  1002000637455042
# traded_time:  1721632991
# traded_price:  9.17
# traded_volume:  1000
# traded_amount:  9170.0
# order_id:  1090640092
# strategy_name:  strategy_buy
# ##################################
# account_id:  55004948
# stock_code:  300240.SZ
# order_type:  23
# traded_id:  1002000637455044
# traded_time:  1721632991
# traded_price:  6.97
# traded_volume:  1000
# traded_amount:  6970.0
# order_id:  1090640089
# strategy_name:  strategy_buy
# ##################################
# account_id:  55004948
# stock_code:  300237.SZ
# order_type:  23
# traded_id:  1002000637455046
# traded_time:  1721632991
# traded_price:  1.22
# traded_volume:  1000
# traded_amount:  1220.0
# order_id:  1090640103
# strategy_name:  strategy_buy
# ##################################
# account_id:  55004948
# stock_code:  001213.SZ
# order_type:  23
# traded_id:  1002000637455048
# traded_time:  1721632991
# traded_price:  3.94
# traded_volume:  1000
# traded_amount:  3940.0
# order_id:  1090640102
# strategy_name:  strategy_buy
# ##################################
# account_id:  55004948
# stock_code:  002670.SZ
# order_type:  23
# traded_id:  1002000637455050
# traded_time:  1721632991
# traded_price:  8.97
# traded_volume:  1000
# traded_amount:  8970.0
# order_id:  1090640096
# strategy_name:  strategy_buy
# ##################################
# account_id:  55004948
# stock_code:  159736.SZ
# order_type:  23
# traded_id:  1002000637455052
# traded_time:  1721632991
# traded_price:  0.663
# traded_volume:  1000
# traded_amount:  663.0
# order_id:  1090640078
# strategy_name:  strategy_buy
# ##################################
# account_id:  55004948
# stock_code:  002584.SZ
# order_type:  23
# traded_id:  1002000637455054
# traded_time:  1721632991
# traded_price:  6.47
# traded_volume:  1000
# traded_amount:  6470.0
# order_id:  1090640094
# strategy_name:  strategy_buy
# ##################################
# account_id:  55004948
# stock_code:  300637.SZ
# order_type:  23
# traded_id:  1002000637455056
# traded_time:  1721632991
# traded_price:  11.13
# traded_volume:  1000
# traded_amount:  11130.0
# order_id:  1090640099
# strategy_name:  strategy_buy
# ##################################
# account_id:  55004948
# stock_code:  300419.SZ
# order_type:  23
# traded_id:  1002000637455058
# traded_time:  1721632991
# traded_price:  5.04
# traded_volume:  1000
# traded_amount:  5040.0
# order_id:  1090640074
# strategy_name:  strategy_buy
# ##################################
# account_id:  55004948
# stock_code:  002168.SZ
# order_type:  23
# traded_id:  1002000637455060
# traded_time:  1721632991
# traded_price:  2.97
# traded_volume:  1000
# traded_amount:  2970.0
# order_id:  1090640091
# strategy_name:  strategy_buy
# ##################################
# account_id:  55004948
# stock_code:  000158.SZ
# order_type:  23
# traded_id:  1002000637455062
# traded_time:  1721632991
# traded_price:  6.12
# traded_volume:  1000
# traded_amount:  6120.0
# order_id:  1090640095
# strategy_name:  strategy_buy
# ##################################
# account_id:  55004948
# stock_code:  300352.SZ
# order_type:  23
# traded_id:  1002000637455064
# traded_time:  1721632991
# traded_price:  3.85
# traded_volume:  1000
# traded_amount:  3850.0
# order_id:  1090640087
# strategy_name:  strategy_buy
# ##################################
# account_id:  55004948
# stock_code:  300072.SZ
# order_type:  23
# traded_id:  1002000637455066
# traded_time:  1721632991
# traded_price:  1.91
# traded_volume:  1000
# traded_amount:  1910.0
# order_id:  1090640101
# strategy_name:  strategy_buy
# ##################################
# account_id:  55004948
# stock_code:  300169.SZ
# order_type:  23
# traded_id:  1002000637455068
# traded_time:  1721632991
# traded_price:  4.84
# traded_volume:  1000
# traded_amount:  4840.0
# order_id:  1090640104
# strategy_name:  strategy_buy
# ##################################
# account_id:  55004948
# stock_code:  000759.SZ
# order_type:  23
# traded_id:  1002000637455070
# traded_time:  1721632991
# traded_price:  3.15
# traded_volume:  1000
# traded_amount:  3150.0
# order_id:  1090640090
# strategy_name:  strategy_buy
# ##################################
# account_id:  55004948
# stock_code:  300050.SZ
# order_type:  23
# traded_id:  1002000637455072
# traded_time:  1721632991
# traded_price:  2.79
# traded_volume:  1000
# traded_amount:  2790.0
# order_id:  1090640070
# strategy_name:  strategy_buy
# ##################################
# account_id:  55004948
# stock_code:  300493.SZ
# order_type:  23
# traded_id:  1002000637455074
# traded_time:  1721632991
# traded_price:  8.15
# traded_volume:  1000
# traded_amount:  8150.0
# order_id:  1090640077
# strategy_name:  strategy_buy
# ##################################
# account_id:  55004948
# stock_code:  002806.SZ
# order_type:  23
# traded_id:  1002000637455076
# traded_time:  1721632991
# traded_price:  9.79
# traded_volume:  1000
# traded_amount:  9790.0
# order_id:  1090640108
# strategy_name:  strategy_buy
# ##################################
# account_id:  55004948
# stock_code:  002178.SZ
# order_type:  23
# traded_id:  1002000637455078
# traded_time:  1721632991
# traded_price:  3.36
# traded_volume:  1000
# traded_amount:  3360.0
# order_id:  1090640106
# strategy_name:  strategy_buy
# ##################################
# account_id:  55004948
# stock_code:  000981.SZ
# order_type:  23
# traded_id:  1002000637455080
# traded_time:  1721632991
# traded_price:  1.11
# traded_volume:  1000
# traded_amount:  1110.0
# order_id:  1090640080
# strategy_name:  strategy_buy
# ##################################
# account_id:  55004948
# stock_code:  002630.SZ
# order_type:  23
# traded_id:  1002000637455082
# traded_time:  1721632991
# traded_price:  2.22
# traded_volume:  1000
# traded_amount:  2220.0
# order_id:  1090640116
# strategy_name:  strategy_buy
# ##################################
# account_id:  55004948
# stock_code:  300162.SZ
# order_type:  23
# traded_id:  1002000637455084
# traded_time:  1721632991
# traded_price:  6.36
# traded_volume:  1000
# traded_amount:  6360.0
# order_id:  1090640121
# strategy_name:  strategy_buy
# ##################################
# account_id:  55004948
# stock_code:  159591.SZ
# order_type:  23
# traded_id:  1002000637455086
# traded_time:  1721632991
# traded_price:  1.006
# traded_volume:  1000
# traded_amount:  1006.0
# order_id:  1090640112
# strategy_name:  strategy_buy
# ##################################
# account_id:  55004948
# stock_code:  300184.SZ
# order_type:  23
# traded_id:  1002000637455088
# traded_time:  1721632991
# traded_price:  4.66
# traded_volume:  1000
# traded_amount:  4660.0
# order_id:  1090640114
# strategy_name:  strategy_buy
# ##################################
# account_id:  55004948
# stock_code:  300759.SZ
# order_type:  23
# traded_id:  1002000637455090
# traded_time:  1721632991
# traded_price:  21.19
# traded_volume:  1000
# traded_amount:  21190.0
# order_id:  1090640111
# strategy_name:  strategy_buy
# ##################################
# account_id:  55004948
# stock_code:  300369.SZ
# order_type:  23
# traded_id:  1002000637455092
# traded_time:  1721632991
# traded_price:  5.09
# traded_volume:  1000
# traded_amount:  5090.0
# order_id:  1090640084
# strategy_name:  strategy_buy
# ##################################
# account_id:  55004948
# stock_code:  002177.SZ
# order_type:  23
# traded_id:  1002000637455094
# traded_time:  1721632991
# traded_price:  3.15
# traded_volume:  1000
# traded_amount:  3150.0
# order_id:  1090640122
# strategy_name:  strategy_buy
# ##################################
# account_id:  55004948
# stock_code:  002611.SZ
# order_type:  23
# traded_id:  1002000637455096
# traded_time:  1721632991
# traded_price:  5.5
# traded_volume:  1000
# traded_amount:  5500.0
# order_id:  1090640069
# strategy_name:  strategy_buy
# ##################################
# account_id:  55004948
# stock_code:  300339.SZ
# order_type:  23
# traded_id:  1002000637455098
# traded_time:  1721632991
# traded_price:  20.8
# traded_volume:  1000
# traded_amount:  20800.0
# order_id:  1090640093
# strategy_name:  strategy_buy
# ##################################
# account_id:  55004948
# stock_code:  002261.SZ
# order_type:  23
# traded_id:  1002000637455100
# traded_time:  1721632992
# traded_price:  11.19
# traded_volume:  1000
# traded_amount:  11190.0
# order_id:  1090640075
# strategy_name:  strategy_buy
# ##################################
# account_id:  55004948
# stock_code:  002321.SZ
# order_type:  23
# traded_id:  1002000637455102
# traded_time:  1721632992
# traded_price:  1.5
# traded_volume:  1000
# traded_amount:  1500.0
# order_id:  1090640129
# strategy_name:  strategy_buy
# ##################################
# account_id:  55004948
# stock_code:  159750.SZ
# order_type:  23
# traded_id:  1002000637455104
# traded_time:  1721632992
# traded_price:  0.667
# traded_volume:  1000
# traded_amount:  667.0
# order_id:  1090640118
# strategy_name:  strategy_buy
# ##################################
# account_id:  55004948
# stock_code:  301036.SZ
# order_type:  23
# traded_id:  1002000637455106
# traded_time:  1721632992
# traded_price:  31.1
# traded_volume:  1000
# traded_amount:  31100.0
# order_id:  1090640126
# strategy_name:  strategy_buy
# ##################################
# account_id:  55004948
# stock_code:  000712.SZ
# order_type:  23
# traded_id:  1002000637455108
# traded_time:  1721632992
# traded_price:  8.4
# traded_volume:  1000
# traded_amount:  8400.0
# order_id:  1090640073
# strategy_name:  strategy_buy
# ##################################
# account_id:  55004948
# stock_code:  002202.SZ
# order_type:  23
# traded_id:  1002000637455110
# traded_time:  1721632992
# traded_price:  7.08
# traded_volume:  1000
# traded_amount:  7080.0
# order_id:  1090640124
# strategy_name:  strategy_buy
# ##################################
# account_id:  55004948
# stock_code:  300611.SZ
# order_type:  23
# traded_id:  1002000637455112
# traded_time:  1721632992
# traded_price:  8.6
# traded_volume:  1000
# traded_amount:  8600.0
# order_id:  1090640120
# strategy_name:  strategy_buy
# ##################################
# account_id:  55004948
# stock_code:  002562.SZ
# order_type:  23
# traded_id:  1002000637455114
# traded_time:  1721632992
# traded_price:  3.45
# traded_volume:  1000
# traded_amount:  3450.0
# order_id:  1090640123
# strategy_name:  strategy_buy
# ##################################
# account_id:  55004948
# stock_code:  300077.SZ
# order_type:  23
# traded_id:  1002001216540028
# traded_time:  1721638431
# traded_price:  10.68
# traded_volume:  1000
# traded_amount:  10680.0
# order_id:  1090642397
# strategy_name:  strategy_buy
# ##################################
# account_id:  55004948
# stock_code:  002077.SZ
# order_type:  23
# traded_id:  1002001216540030
# traded_time:  1721638431
# traded_price:  12.12
# traded_volume:  1000
# traded_amount:  12120.0
# order_id:  1090642411
# strategy_name:  strategy_buy
# ##################################
# account_id:  55004948
# stock_code:  000981.SZ
# order_type:  23
# traded_id:  1002001216540032
# traded_time:  1721638431
# traded_price:  1.11
# traded_volume:  1000
# traded_amount:  1110.0
# order_id:  1090642409
# strategy_name:  strategy_buy
# ##################################
# account_id:  55004948
# stock_code:  300050.SZ
# order_type:  23
# traded_id:  1002001216540034
# traded_time:  1721638431
# traded_price:  2.79
# traded_volume:  1000
# traded_amount:  2790.0
# order_id:  1090642399
# strategy_name:  strategy_buy
# ##################################
# account_id:  55004948
# stock_code:  000008.SZ
# order_type:  23
# traded_id:  1002001216540036
# traded_time:  1721638431
# traded_price:  2.03
# traded_volume:  1000
# traded_amount:  2029.9999999999998
# order_id:  1090642400
# strategy_name:  strategy_buy
# ##################################
# account_id:  55004948
# stock_code:  300352.SZ
# order_type:  23
# traded_id:  1002001216540038
# traded_time:  1721638431
# traded_price:  3.85
# traded_volume:  1000
# traded_amount:  3850.0
# order_id:  1090642416
# strategy_name:  strategy_buy
# ##################################
# account_id:  55004948
# stock_code:  159736.SZ
# order_type:  23
# traded_id:  1002001216540040
# traded_time:  1721638431
# traded_price:  0.663
# traded_volume:  1000
# traded_amount:  663.0
# order_id:  1090642407
# strategy_name:  strategy_buy
# ##################################
# account_id:  55004948
# stock_code:  002611.SZ
# order_type:  23
# traded_id:  1002001216540042
# traded_time:  1721638431
# traded_price:  5.5
# traded_volume:  1000
# traded_amount:  5500.0
# order_id:  1090642398
# strategy_name:  strategy_buy
# ##################################
# account_id:  55004948
# stock_code:  000712.SZ
# order_type:  23
# traded_id:  1002001216540044
# traded_time:  1721638431
# traded_price:  8.4
# traded_volume:  1000
# traded_amount:  8400.0
# order_id:  1090642402
# strategy_name:  strategy_buy
# ##################################
# account_id:  55004948
# stock_code:  300493.SZ
# order_type:  23
# traded_id:  1002001216540046
# traded_time:  1721638431
# traded_price:  8.15
# traded_volume:  1000
# traded_amount:  8150.0
# order_id:  1090642406
# strategy_name:  strategy_buy
# ##################################
# account_id:  55004948
# stock_code:  300419.SZ
# order_type:  23
# traded_id:  1002001216540048
# traded_time:  1721638431
# traded_price:  5.04
# traded_volume:  1000
# traded_amount:  5040.0
# order_id:  1090642403
# strategy_name:  strategy_buy
# ##################################
# account_id:  55004948
# stock_code:  300379.SZ
# order_type:  23
# traded_id:  1002001216540050
# traded_time:  1721638431
# traded_price:  8.32
# traded_volume:  1000
# traded_amount:  8320.0
# order_id:  1090642405
# strategy_name:  strategy_buy
# ##################################
# account_id:  55004948
# stock_code:  300369.SZ
# order_type:  23
# traded_id:  1002001216540052
# traded_time:  1721638431
# traded_price:  5.09
# traded_volume:  1000
# traded_amount:  5090.0
# order_id:  1090642413
# strategy_name:  strategy_buy
# ##################################
# account_id:  55004948
# stock_code:  002531.SZ
# order_type:  23
# traded_id:  1002001216540054
# traded_time:  1721638431
# traded_price:  8.48
# traded_volume:  1000
# traded_amount:  8480.0
# order_id:  1090642408
# strategy_name:  strategy_buy
# ##################################
# account_id:  55004948
# stock_code:  002261.SZ
# order_type:  23
# traded_id:  1002001216540056
# traded_time:  1721638431
# traded_price:  11.19
# traded_volume:  1000
# traded_amount:  11190.0
# order_id:  1090642404
# strategy_name:  strategy_buy
# ##################################
# account_id:  55004948
# stock_code:  300240.SZ
# order_type:  23
# traded_id:  1002001216540058
# traded_time:  1721638431
# traded_price:  6.97
# traded_volume:  1000
# traded_amount:  6970.0
# order_id:  1090642418
# strategy_name:  strategy_buy
# ##################################
# 2024-07-22 20:18:09.126699 on_account_status
# 2024-07-22 20:19:45.719596 on_account_status
# 2024-07-22 20:19:45.835450 on_account_status
# 2024-07-22 20:19:47.909021 on_account_status
# 2024-07-22 20:35:02.713545 on_account_status
# 2024-07-22 20:35:13.390215 on_account_status
# 2024-07-22 20:35:13.390215 on_account_status
# 2024-07-22 20:35:13.390215 on_account_status
# 2024-07-22 20:37:13.347092 on_account_status

# %% [markdown]
# ***<font color=steel
#     size=5
#        face=雅黑>
# <mark>卖出</mark>
# </font>***

# %%
#TODO：上涨过程中突然跌量
#TODO: 连续两天成交量是前5天的3倍，提高卖出上线至15%，20%，25%不等
#TODO: 持有5天以上，收益率为正
def check_for_selling(stock_list, position_dict):
    import backtest as bt
    from backtest import Context 
    import pandas as pd
    count = 0
    import datetime
    current_date = datetime.datetime.now() + datetime.timedelta(days=1)
    #current_date = datetime.datetime.strptime('20240621', "%Y%m%d")
    c_date_str = current_date.strftime("%Y%m%d")
    #TODO: get accurate start date
    start_date = current_date
    s_date_str = start_date.strftime("%Y%m%d")
    ret = pd.DataFrame()
    #stock_list = ['517520.SH']
    for key in stock_list:
        if position_dict[key]['can_use_volume'] == 0:
            continue
        logging.info("stock code: " + key)
        code = key.split('.')[0]
        #print(code)
        market = key.split('.')[1]
        
        global context
        context = Context(market, 100000000, s_date_str, c_date_str)
        context.bkt_dt = current_date.strftime("%Y%m%d")
        #TODO：get_market_data_ex
        hist_data = bt.get_hist_data_by_count(context, code, 1, 'front', 'tick', ['lastPrice'])
        #logging.info(hist_data)
        last_price = hist_data.values[0][0]
        logging.info("last_price: " + str(last_price))
        avg_price = position_dict[key]['avg_price']
        logging.info("avg_price: " + str(avg_price))
        
        roe = (last_price / avg_price) - 1
        logging.info("roe: " + str(roe))
        #TODO: 创业板涨跌幅为20%~-10%，其他为10%~-5%
        if roe >= 0.1  or roe <= -0.05:
            logging.warning("sell " + str(position_dict[key]['can_use_volume']) + " shares of " + key)
            async_seq = xt_trader.order_stock_async(acc, 
                                                    key, 
                                                    xtconstant.STOCK_SELL, 
                                                    position_dict[key]['can_use_volume'], 
                                                    xtconstant.FIX_PRICE,
                                                    last_price,
                                                    'strategy_sell'
                                                    )
#xtconstant.FIX_PRICE,
#xtconstant.LATEST_PRICE                                                    last_price,

# %%
def cancel_untraded_order(acc):
    cancelable_order_list = xt_trader.query_stock_orders(acc, cancelable_only = True)
    for cancelable_order in cancelable_order_list:
        cur_time = datetime.datetime.now().timestamp()
        print(cur_time)
        order_time = cancelable_order.order_time
        print(order_time)
        if cur_time - order_time >= 300:
            cancel_result = xt_trader.cancel_order_stock_async(acc, cancelable_order.order_id)

# %%
while True:
    hour = datetime.datetime.now().hour
    minute = datetime.datetime.now().minute
    cur_time = hour * 100 + minute
    logging.info("check time: " + str(cur_time))
    if cur_time < 930 or (cur_time > 1130 and cur_time < 1300):
        logging.info("NOT TRADING TIME")
        time.sleep(60)
        continue
    if  cur_time > 1500:
        break
    cancel_untraded_order(acc)
    stock_list, position_dict = get_hold_position()
    check_for_selling(stock_list, position_dict)
    time.sleep(60)

# %% [markdown]
# ***<font color=steel
#     size=5
#        face=雅黑>
# <mark>当日成交记录存储</mark>
# </font>***

# %%
def record_today_trades():
    trades = xt_trader.query_stock_trades(acc)
    col_list = ['account_type',
               'account_id',
               'stock_code',
               'order_type',
               'traded_id',
               'traded_time ',
               'traded_price',
               'traded_volume',
               'traded_amount',
               'order_id',
               'order_sysid ',
               'strategy_name',
               'order_remark',
               'direction',
               'offset_flag']
    
    data = []
    
    for trade in trades:
        col_data = [
                trade.account_type,
                trade.account_id,
                trade.stock_code,
                trade.order_type,
                trade.traded_id,
                trade.traded_time,
                trade.traded_price,
                trade.traded_volume ,
                trade.traded_amount ,
                trade.order_id,
                trade.order_sysid,
                trade.strategy_name ,
                trade.order_remark,
                trade.direction,
                trade.offset_flag
                ]
        data.append(col_data)
    current_date = datetime.datetime.now()
    c_date_str = current_date.strftime("%Y%m%d")
    trades_df = pd.DataFrame(data, columns=col_list)
    trades_df.to_csv('trade_record_' + c_date_str + '.csv', index=False)
record_today_trades()
